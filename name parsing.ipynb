# %%
import requests
from bs4 import BeautifulSoup
URL = "https://www.pulsarsecurity.com/team"
page = requests.get(URL)

print(page.text)
# Out:
# <!doctype html><!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="author" content="Pulsar Security">
#     <meta name="description" content="Meet the Pulsar Security Team. We are security consultants who pursue mastery and expertise of complex subject matter to address challenging problems.">
#     <meta name="generator" content="HubSpot">
#     <title>Team | Pulsar Security</title>
#     <link rel="shortcut icon" href="https://www.pulsarsecurity.com/hubfs/fav-1.png">
#
#
#
#     <meta property="og:description" content="Meet the Pulsar Security Team. We are security consultants who pursue mastery and expertise of complex subject matter to address challenging problems.">
#     <meta property="og:title" content="Team | Pulsar Security">
#     <meta name="twitter:description" content="Meet the Pulsar Security Team. We are security consultants who pursue mastery and expertise of complex subject matter to address challenging problems.">
#     <meta name="twitter:title" content="Team | Pulsar Security">
#
#
#
#
#     <style>
# a.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:'›';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}
# </style>
#
# <link rel="stylesheet" href="https://www.pulsarsecurity.com/hubfs/pulsar/slider/slick.min.css">
#
#
#
# <!--  Added by GoogleAnalytics integration -->
# <script>
# var _hsp = window._hsp = window._hsp || [];
# _hsp.push(['addPrivacyConsentListener', function(consent) { if (consent.allowed || (consent.categories && consent.categories.analytics)) {
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create','UA-127323955-1','auto');
#   ga('send','pageview');
# }}]);
# </script>
#
# <!-- /Added by GoogleAnalytics integration -->
#
#     <link rel="canonical" href="https://www.pulsarsecurity.com/team">
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="google-site-verification" content="mkdrFh5Oo1eHDeY46es3ww14t01U7yJeocXkqSjBm5A">
#
# <!-- Bootstrap -->
# <link href="https://www.pulsarsecurity.com/hubfs/pulsar/bootstrap/bootstrap-grid.min.css" rel="stylesheet">
# <link href="https://www.pulsarsecurity.com/hubfs/pulsar/bootstrap/bootstrap-utilities.min.css" rel="stylesheet">
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '3323484487762706');
# fbq('track', 'PageView');
# </script>
# <noscript>
# &lt;img  height="1" width="1" src="https://www.facebook.com/tr?id=3323484487762706&amp;amp;ev=PageView&amp;amp;noscript=1"&gt;
# </noscript>
# <!-- End Facebook Pixel Code -->
# <meta property="og:url" content="https://www.pulsarsecurity.com/team">
# <meta name="twitter:card" content="summary">
# <meta http-equiv="content-language" content="en">
# <link rel="stylesheet" href="//cdn2.hubspot.net/hub/7052064/hub_generated/template_assets/1669421855020/hubspot/hubspot_default/shared/responsive/layout.min.css">
#
#
# <link rel="stylesheet" href="https://www.pulsarsecurity.com/hs-fs/hub/6072841/hub_generated/template_assets/16770281418/1661520429582/Pulsar/Coded_Files/pulsar.min.css">
#
#
#
#
# </head>
# <body class="hs-lay lower team-page   hs-content-id-17570113547 hs-site-page page " style="">
#     <div class="header-container-wrapper">
#     <div class="header-container container-fluid">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-global_group " style="" data-widget-type="global_group" data-x="0" data-w="12">
# <div class="" data-global-widget-path="generated_global_groups/16959614135.html"><div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell cm-header-wrapper" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-2 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell page-center header-header" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-3 ">
# <div class="row-fluid ">
# <div class="span3 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="3">
# <div id="hs_cos_wrapper_module_157011336470722" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-logo" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="custom-logo">
#   <a href="https://www.pulsarsecurity.com">
#
#     <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/pulsar-white.png" alt="pulsar-white">
#
#   </a>
# </div></div>
#
# </div><!--end widget-span -->
# <div class="span9 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="3" data-w="9">
# <div id="hs_cos_wrapper_module_157011695326846" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="custom-menu-primary">
#   <div class="hs-menu-wrapper active-branch flyouts hs-menu-flow-horizontal">
#     <ul>
#
#
#
#       <li class="hs-menu-item hs-menu-depth-1   hs-item-has-children">
#         <a href="https://www.pulsarsecurity.com/services">Services</a>
#
#         <ul class="hs-menu-children-wrapper ">
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://www.pulsarsecurity.com/pulsar-cybershield">Pulsar Cyber Shield</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://www.pulsarsecurity.com/custom-services">Custom Services</a>
#
#           </li>
#
#         </ul>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1   hs-item-has-children">
#         <a href="https://www.pulsarsecurity.com/industries">Industries</a>
#
#         <ul class="hs-menu-children-wrapper ">
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://www.pulsarsecurity.com/clients-we-serve">Clients We Serve</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://www.pulsarsecurity.com/education">Education</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://www.pulsarsecurity.com/cmaa">Hospitality - CMAA</a>
#
#           </li>
#
#         </ul>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1   ">
#         <a href="https://www.pulsarsecurity.com/partners">Resellers</a>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1   hs-item-has-children">
#         <a href="https://blog.pulsarsecurity.com">Media</a>
#
#         <ul class="hs-menu-children-wrapper ">
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://blog.pulsarsecurity.com">Blogs</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://blog.pulsarsecurity.com/downloads">Downloadable Content</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://blog.pulsarsecurity.com/podcasts">Podcasts</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://blog.pulsarsecurity.com/videos">Videos</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://blog.pulsarsecurity.com/webinars-events">Webinars and Events</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://blog.pulsarsecurity.com/cyber-trends">Cyber Trends</a>
#
#           </li>
#
#         </ul>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1 active-branch  hs-item-has-children">
#         <a href="https://www.pulsarsecurity.com/about">Company</a>
#
#         <ul class="hs-menu-children-wrapper active-branch">
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://www.pulsarsecurity.com/who-is-pulsar-security">About</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2 active active-branch ">
#             <a href="https://www.pulsarsecurity.com/team">Team</a>
#
#           </li>
#
#           <li class="hs-menu-item hs-menu-depth-2  ">
#             <a href="https://www.pulsarsecurity.com/contact">Contact</a>
#
#           </li>
#
#         </ul>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1 cta-menu-item">
#         <span id="hs_cos_wrapper_module_157011695326846_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_cta" style="" data-hs-cos-general-type="widget" data-hs-cos-type="cta"><!--HubSpot Call-to-Action Code --><span class="hs-cta-wrapper" id="hs-cta-wrapper-2d2026b1-2282-4a2f-9409-e8e82b28582d"><span class="hs-cta-node hs-cta-2d2026b1-2282-4a2f-9409-e8e82b28582d" id="hs-cta-2d2026b1-2282-4a2f-9409-e8e82b28582d"><!--[if lte IE 8]><div id="hs-cta-ie-element"></div><![endif]--><a href="https://cta-redirect.hubspot.com/cta/redirect/6072841/2d2026b1-2282-4a2f-9409-e8e82b28582d"><img class="hs-cta-img" id="hs-cta-img-2d2026b1-2282-4a2f-9409-e8e82b28582d" style="border-width:0px;" src="https://no-cache.hubspot.com/cta/default/6072841/2d2026b1-2282-4a2f-9409-e8e82b28582d.png" alt="Get Cyber Shield"></a></span><script charset="utf-8" src="/hs/cta/cta/current.js"></script><script type="text/javascript"> hbspt.cta._relativeUrls=true;hbspt.cta.load(6072841, '2d2026b1-2282-4a2f-9409-e8e82b28582d', {"useNewLoader":"true","region":"na1"}); </script></span><!-- end HubSpot Call-to-Action Code --></span>
#       </li>
#
#     </ul>
#   </div>
# </div></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
# </div>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
#     </div><!--end header -->
# </div><!--end header wrapper -->
#
# <div class="body-container-wrapper">
#     <div class="body-container container-fluid">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell hero-content" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-2 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_157046819680532" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
# <section class="custom-banner hero-lower hero-lower-default large">
#   <div class="background-image-container hero-lower-image" style="background-image: url('https://www.pulsarsecurity.com/hubfs/pulsar/images/hero-lower.jpg');"></div>
#   <div class="background-image-container" style="background-image: url('https://www.pulsarsecurity.com/hubfs/pulsar/images/mesh.svg');"></div>
#   <div class="hero-container">
#
#     <div class="hero-content-container">
#       <div class="hero-tag-line">
#
#       </div>
#       <h1 class="hero-headline">Team</h1>
#     </div>
#
#   </div>
# </section>
# </div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-3 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell page-center content-wrapper" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-4 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1570639114372410" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><section id="block-team" class="column-content block-content-team">
#   <div class="column-content-wrapper">
#     <ul class="block-team-list">
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/patrick-hynds" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/patrick-hynds.jpg" alt="patrick-hynds" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Patrick Hynds</h3>
#             <h4 class="block-team-role">Chief Executive Officer</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/duane-laflotte" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/duane-laflotte.jpg" alt="duane-laflotte" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Duane Laflotte</h3>
#             <h4 class="block-team-role">Chief Technology Officer, Senior Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/OSWE.png" alt="OSWE">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/osce%20(1).png" alt="osce (1)">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/oscp.png" alt="oscp">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png" alt="Template_GXPN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/OSEP.png" alt="OSEP">
#                 </li>
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/sabine-hynds" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/Sabine.jpg" alt="Sabine" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Sabine Hynds</h3>
#             <h4 class="block-team-role">Chief Financial Officer, Human Resources Manager</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/ahren-thielker" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/ahren-thielker.jpg" alt="ahren-thielker" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Ahren Thielker</h3>
#             <h4 class="block-team-role">Chief Information Officer, Network Security Engineer, Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png" alt="Template_GPEN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_GPYC_Dig_badge_logo-1.png" alt="linkedin_thumb_GPYC_Dig_badge_logo-1">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_Template_GAWN-1-1.png" alt="linkedin_thumb_Template_GAWN-1-1">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GWAPT.png" alt="Template_GWAPT">
#                 </li>
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/jarrod-laflotte" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/Duane-laflotte.jpg" alt="Duane-laflotte" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Jarrod Laflotte</h3>
#             <h4 class="block-team-role">Researcher, Senior Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/oscp.png" alt="oscp">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png" alt="Template_GXPN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486.png" alt="AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/OSEP.png" alt="OSEP">
#                 </li>
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/vaughn-temple" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/vaughn.jpg" alt="vaughn" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Vaughn Temple</h3>
#             <h4 class="block-team-role">Researcher, Senior Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/oscp.png" alt="oscp">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png" alt="Template_GXPN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/certifications/cissp.gif" alt="cissp">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486.png" alt="AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/OSEP.png" alt="OSEP">
#                 </li>
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/tim-connell" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/tim-connell.jpg" alt="tim-connell" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Tim Connell</h3>
#             <h4 class="block-team-role">Director, Cybersecurity Services Delivery</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/oscp.png" alt="OSCP">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/WiFu-OSWP-badge.png" alt="WiFu-OSWP-badge">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_Template_GAWN-1-1.png" alt="linkedin_thumb_Template_GAWN-1-1">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png" alt="Template_GPEN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GCIA.png" alt="Template_GCIA">
#                 </li>
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/manny-resendes" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/manny.jpeg" alt="manny" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Manny Resendes</h3>
#             <h4 class="block-team-role">Software Development Team Manager</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/jason-nickola" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/jason-nickola.jpg" alt="jason-nickola" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Jason Nickola</h3>
#             <h4 class="block-team-role">Senior Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/GSE_352x352.png" alt="GSE_352x352">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/osce.png" alt="osce">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png" alt="Template_GXPN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/oscp.png" alt="oscp">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GREM.png" alt="Template_GREM">
#                 </li>
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/corey-belanger" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/corey-belanger.jpg" alt="corey-belanger" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Corey Belanger</h3>
#             <h4 class="block-team-role">QA Lead, Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GCIH.png" alt="Template_GCIH">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_GPYC_Dig_badge_logo-1.png" alt="linkedin_thumb_GPYC_Dig_badge_logo-1">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GWAPT.png" alt="Template_GWAPT">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png" alt="Template_GPEN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/oscp.png" alt="oscp">
#                 </li>
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/marshall-thompson" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/marshall-thompson.jpg" alt="marshall-thompson" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Marshall Thompson</h3>
#             <h4 class="block-team-role">Software Engineer, Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GWAPT.png" alt="Template_GWAPT">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_GPYC_Dig_badge_logo-1.png" alt="linkedin_thumb_GPYC_Dig_badge_logo-1">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png" alt="Template_GPEN">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/Certifications/comptia-network.png" alt="comptia-network">
#                 </li>
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/yavuz-dereli" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/yavuz-dereli.jpg" alt="yavuz-dereli" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Yavuz Dereli</h3>
#             <h4 class="block-team-role">Network Engineer</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/CCNA-ACS-263x230.png" alt="CCNA">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/MTA-Database-Fundamentals-2019.png" alt="MTA-Database-Fundamentals-2019">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/MTA-Security-Fundamentals-2019.png" alt="MTA-Security-Fundamentals-2019">
#                 </li>
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/wes-molaski" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/wes-molaski.jpg" alt="wes-molaski" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Wes Molaski</h3>
#             <h4 class="block-team-role">Security Consultant</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/peyton-somerville" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/peyton.jpg" alt="peyton" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Peyton Somerville</h3>
#             <h4 class="block-team-role">Junior Security Engineer, leads Pulsar Explore Internship Program</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/jill-stagner" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/jill.jpg" alt="jill" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Jill Stagner</h3>
#             <h4 class="block-team-role">Director of Marketing and Program Development</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/katie-gusella" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/IMG_0194.jpeg" alt="Katie-Gusella" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Katie Gusella</h3>
#             <h4 class="block-team-role">Director of Business Development</h4>
#             <ul class="block-team-certifications-list">
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/BMI_Club_Management__3_.png" alt="BMI_Club_Management__3_">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/BMI_Leadership_Principles__3_.png" alt="BMI_Leadership_Principles__3_">
#                 </li>
#
#
#                 <li class="block-team-certifications-item">
#                   <img src="https://www.pulsarsecurity.com/hubfs/BMI_GM-COO__3_.png" alt="BMI_GM-COO__3_">
#                 </li>
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/jim-bail" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/jim-bail.jpg" alt="jim-bail" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Jim Bail</h3>
#             <h4 class="block-team-role">Senior Enterprise Account Manager</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#       <li class="block-team-item">
#
#         <a href="https://www.pulsarsecurity.com/nikki-telowitz" class="block-team-link">
#
#         <div class="block-team-wrapper">
#           <div class="block-team-left">
#
#               <img src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/nikki-telowitz.jpg" alt="nikki-telowitz" class="block-team-image">
#
#           </div>
#           <div class="block-team-right">
#             <h3 class="block-team-name">Nikki Telowitz</h3>
#             <h4 class="block-team-role">Senior Enterprise Account Manager</h4>
#             <ul class="block-team-certifications-list">
#
#
#
#
#
#             </ul>
#           </div>
#         </div>
#
#         </a>
#
#       </li>
#
#     </ul>
#   </div>
# </section></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-5 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-widget_container main-content h2-lower" style="" data-widget-type="widget_container" data-x="0" data-w="12">
# <span id="hs_cos_wrapper_module_140190329510711990" class="hs_cos_wrapper hs_cos_wrapper_widget_container hs_cos_wrapper_type_widget_container" style="" data-hs-cos-general-type="widget_container" data-hs-cos-type="widget_container"><div id="hs_cos_wrapper_widget_151811990214758" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><span id="hs_cos_wrapper_widget_151811990214758_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text"><h2 class="p1" style="text-align: center;">We are offensive security experts and want to use those skills to help you defend your assets.</h2></span></div></span>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-6 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-widget_container " style="" data-widget-type="widget_container" data-x="0" data-w="12">
# <span id="hs_cos_wrapper_module_1570640235359215" class="hs_cos_wrapper hs_cos_wrapper_widget_container hs_cos_wrapper_type_widget_container" style="" data-hs-cos-general-type="widget_container" data-hs-cos-type="widget_container"><div id="hs_cos_wrapper_widget_1630420430271" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><section class="cm-comming-soon overlay-cta pulsar-gradient gradient-bg-top">
#   <div class="background-image-container" style="background-image: url('https://www.pulsarsecurity.com/hubfs/cyber-shield.jpg');"></div>
#   <div class="overlay-cta-wrapper">
#     <div class="overlay-cta-content">
#       <h3 class="overlay-cta-header">
#         Minimize your Cyber Risks
#       </h3>
#       <div class="overlay-cta-form-wrapper">
#         <h4 class="overlay-cta-form-header">
#           A comprehensive array of services securing data, network &amp; firmware configurations, &amp; your wireless network.
#         </h4>
#         <div class="gf_browser_chrome gform_wrapper" id="gform_wrapper_1">
#           <span id="hs_cos_wrapper_widget_1630420430271_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_cta" style="" data-hs-cos-general-type="widget" data-hs-cos-type="cta"><!--HubSpot Call-to-Action Code --><span class="hs-cta-wrapper" id="hs-cta-wrapper-4e851884-efb1-4af4-892c-f42dfd442a30"><span class="hs-cta-node hs-cta-4e851884-efb1-4af4-892c-f42dfd442a30" id="hs-cta-4e851884-efb1-4af4-892c-f42dfd442a30"><!--[if lte IE 8]><div id="hs-cta-ie-element"></div><![endif]--><a href="https://cta-redirect.hubspot.com/cta/redirect/6072841/4e851884-efb1-4af4-892c-f42dfd442a30"><img class="hs-cta-img" id="hs-cta-img-4e851884-efb1-4af4-892c-f42dfd442a30" style="border-width:0px;" src="https://no-cache.hubspot.com/cta/default/6072841/4e851884-efb1-4af4-892c-f42dfd442a30.png" alt="Learn More&nbsp;"></a></span><script charset="utf-8" src="/hs/cta/cta/current.js"></script><script type="text/javascript"> hbspt.cta._relativeUrls=true;hbspt.cta.load(6072841, '4e851884-efb1-4af4-892c-f42dfd442a30', {"useNewLoader":"true","region":"na1"}); </script></span><!-- end HubSpot Call-to-Action Code --></span>
#         </div>
#       </div>
#     </div>
#     <div class="cta-image">
#
#       <br>
#
#
#     </div>
#   </div>
# </section></div></span>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
#     </div><!--end body -->
# </div><!--end body wrapper -->
#
# <div class="footer-container-wrapper">
#     <div class="footer-container container-fluid">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-global_group " style="" data-widget-type="global_group" data-x="0" data-w="12">
# <div class="" data-global-widget-path="generated_global_groups/16938988855.html"><div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell cm-footer-wrapper" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-2 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1619031993160130" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="certifications-slider row-fluid-wrapper">
#   <div class="row-fluid">
#     <div class="page-center certifications-slider-container">
#       <h3>100% of the team holds advanced cybersecurity certifications.</h3>
#       <div class="slider">
#         <div class="slider__slide">
#             <ul class="slider-list">
#             <li>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/CEH%20Certified%20Ethical%20Hacker%20Badge.png" alt="Certified Ethical Hacker">
#                     <div class="certification-slider-title">Certified Ethical Hacker</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/cissp-01.png" alt="Certified Information Systems Security Professional">
#                     <div class="certification-slider-title">Certified Information Systems Security Professional</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/download%20(1).png" alt="CompTIA Security+ Certified">
#                     <div class="certification-slider-title">CompTIA Security+ Certified</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/oswp1.png" alt="OSWP Offensive Security">
#                     <div class="certification-slider-title">OSWP Offensive Security</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/GSE_352x352.png" alt="GIAC Security Expert">
#                     <div class="certification-slider-title">GIAC Security Expert</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/osce%20(1).png" alt="Offensive Security Certified Expert">
#                     <div class="certification-slider-title">Offensive Security Certified Expert</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/oscp.png" alt="Offensive Security Certified Professional">
#                     <div class="certification-slider-title">Offensive Security Certified Professional</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png" alt="GIAC Exploit Researcher and Advanced Penetration Tester">
#                     <div class="certification-slider-title">GIAC Exploit Researcher and Advanced Penetration Tester</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GWAPT.png" alt="GIAC Web Application Penetration Tester">
#                     <div class="certification-slider-title">GIAC Web Application Penetration Tester</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png" alt="GIAC Certified Penetration Tester">
#                     <div class="certification-slider-title">GIAC Certified Penetration Tester</div>
#                 </div>
#             </li>
#             </ul>
#         </div>
#         <div class="slider__slide">
#             <ul class="slider-list">
#             <li>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_Template_GMOB-1-1.png" alt="GIAC Mobile Device Security Analyst">
#                     <div class="certification-slider-title">GIAC Mobile Device Security Analyst</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GCIH.png" alt="GIAC Certified Incident Handler">
#                     <div class="certification-slider-title">GIAC Certified Incident Handler</div>
#                 </div>
#                 <div class="certificate-wrapper">
# ...
#                     <div class="certification-slider-title">GIAC Security Essentials Certification</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/GDAT.png" alt="GIAC Defending Advanced Threats">
#                     <div class="certification-slider-title">GIAC Defending Advanced Threats</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/GLEG-Update.png" alt="GIAC Law of Data Security &amp; Investigation">
#                     <div class="certification-slider-title">GIAC Law of Data Security &amp; Investigation</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/download.png" alt="CompTIA Network+ Certified">
#                     <div class="certification-slider-title">CompTIA Network+ Certified</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/SAI_BadgeSizes_DigitalBadging_CSP-SM-1.png" alt="Scrum Alliance CSP-SM Certified">
#                     <div class="certification-slider-title">Scrum Alliance CSP-SM Certified</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/MTA-Security-Fundamentals-2019-1.png" alt="Microsoft MTA Security Fundamentals">
#                     <div class="certification-slider-title">Microsoft MTA Security Fundamentals</div>
#                 </div>
#             </li>
#             </ul>
#         </div>
#         <div class="slider__slide">
#             <ul class="slider-list">
#             <li>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/MTA-Database_Fundamentals-1.png" alt="Microsoft MTA Database Fundamentals">
#                     <div class="certification-slider-title">Microsoft MTA Database Fundamentals</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/CCNA-Certification-Logo-1.jpg" alt="CISCO Certified CCNA">
#                     <div class="certification-slider-title">CISCO Certified CCNA</div>
#                 </div>
#                 <div class="certificate-wrapper">
#                     <img class="certification-slider-image" src="https://www.pulsarsecurity.com/hubfs/Certifications/AWS-SolArchitect-Associate-1.png" alt="AWS Certified Solutions Architect Associate">
#                     <div class="certification-slider-title">AWS Certified Solutions Architect Associate</div>
#                 </div>
#             </li>
#             </ul>
#         </div>
#       </div>
#     </div>
#   </div>
# </div></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-3 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell page-center" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-4 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell cm-inner-grp" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-5 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell footer-nav-social" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-2 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget nav-footer" style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1570124685820230" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="custom-menu-primary">
#   <div class="hs-menu-wrapper active-branch flyouts hs-menu-flow-horizontal">
#     <ul>
#
#
#
#       <li class="hs-menu-item hs-menu-depth-1   ">
#         <a href="https://www.pulsarsecurity.com">Home</a>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1   ">
#         <a href="https://www.pulsarsecurity.com/services">Services</a>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1   ">
#         <a href="https://www.pulsarsecurity.com/partners">Partners</a>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1   ">
#         <a href="https://www.pulsarsecurity.com/about">About</a>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1   ">
#         <a href="https://www.pulsarsecurity.com/contact">Contact</a>
#
#       </li>
#
#
#       <li class="hs-menu-item hs-menu-depth-1 cta-menu-item">
#         <span id="hs_cos_wrapper_module_1570124685820230_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_cta" style="" data-hs-cos-general-type="widget" data-hs-cos-type="cta"><!--HubSpot Call-to-Action Code --><span class="hs-cta-wrapper" id="hs-cta-wrapper-47e11341-435a-4878-bc95-cfb9afb90f6c"><span class="hs-cta-node hs-cta-47e11341-435a-4878-bc95-cfb9afb90f6c" id="hs-cta-47e11341-435a-4878-bc95-cfb9afb90f6c"><!--[if lte IE 8]><div id="hs-cta-ie-element"></div><![endif]--><a href="https://cta-redirect.hubspot.com/cta/redirect/6072841/47e11341-435a-4878-bc95-cfb9afb90f6c"><img class="hs-cta-img" id="hs-cta-img-47e11341-435a-4878-bc95-cfb9afb90f6c" style="border-width:0px;" src="https://no-cache.hubspot.com/cta/default/6072841/47e11341-435a-4878-bc95-cfb9afb90f6c.png" alt="Contact"></a></span><script charset="utf-8" src="/hs/cta/cta/current.js"></script><script type="text/javascript"> hbspt.cta._relativeUrls=true;hbspt.cta.load(6072841, '47e11341-435a-4878-bc95-cfb9afb90f6c', {"useNewLoader":"true","region":"na1"}); </script></span><!-- end HubSpot Call-to-Action Code --></span>
#       </li>
#
#     </ul>
#   </div>
# </div></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-2 row-number-2 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1570124891507289" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="footer-social-media">
#   <ul class="cher-links">
#     <li class="cher-link-item cher-link-linkedin">
#       <a id="cher-link-email" class="cher-link" href="https://www.linkedin.com/company/pulsar-security" title="Follow us on LinkedIn" rel="nofollow,noopener" target="_blank">
#         <i class="icon icon-linkedin" style="background-image: none;">
#           <svg xmlns="http://www.w3.org/2000/svg" width="64" height="64" viewBox="0 0 64 64">
#             <path d="M64 38.57c0-.58 0-1.17-.04-1.75-.08-1.33-.25-2.65-.53-3.96-.38-1.74-.94-3.42-1.79-4.99-1.51-2.8-3.67-4.9-6.59-6.2-1.67-.74-3.42-1.14-5.24-1.29-1.67-.13-3.33-.08-4.97.25-2.5.51-4.69 1.62-6.52 3.42-.86.84-1.59 1.77-2.26 2.76-.05.07-.07.16-.2.21V21.3H22.14v.26c.01.44.03.88.03 1.32.02 2.4.04 4.8.04 7.2 0 3.85-.01 7.7-.01 11.54 0 2.48-.01 4.97-.01 7.45l-.03 7.82c-.01 1.89-.01 3.78-.02 5.67h13.74c0-.11-.01-.22-.01-.32V39.3c0-.77.05-1.53.2-2.28.11-.54.31-1.03.55-1.52.65-1.29 1.53-2.38 2.74-3.18 1.09-.72 2.29-1.09 3.59-1.15.81-.03 1.61.02 2.4.23 1.57.41 2.75 1.34 3.57 2.73.53.9.84 1.88 1.05 2.9.22 1.07.31 2.16.31 3.25v22.19c0 .03 0 .07-.01.1h13.69c.01-.11.02-.23.02-.35.02-7.87.02-15.76.02-23.65zM14.55 21.32H.85v41.26h13.69c.01-.12.03-.25.03-.37V21.43c0-.03-.01-.07-.02-.11zM12.93 3.08c-1.09-.89-2.35-1.37-3.72-1.57-.22-.03-.44-.07-.66-.1h-1.5c-.22.03-.44.07-.66.1-1.6.24-3.04.83-4.24 1.96C1.07 4.49.42 5.73.15 7.18c-.05.24-.1.48-.15.73v1.3c.05.22.1.43.14.65.41 2.21 1.6 3.86 3.58 4.92 1.04.56 2.15.82 3.32.89 1.27.07 2.51-.05 3.71-.48 1.8-.64 3.17-1.77 4.01-3.5.69-1.42.86-2.92.57-4.48-.3-1.65-1.07-3.05-2.4-4.13z"></path>
#           </svg>
#         </i>
#       </a>
#     </li>
#     <li class="cher-link-item cher-link-twitter">
#       <a id="cher-link-email" class="cher-link" href="https://twitter.com/PulsarSecurity" title="Follow us on Twitter" rel="nofollow,noopener" target="_blank">
#         <i class="icon icon-twitter" style="background-image: none;">
#           <svg width="512px" height="417px" viewBox="0 0 512 417" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#             <path d="M512,49.2 C493,57.6 472.7,63.1 451.5,65.8 C473.3,52.8 489.9,32.4 497.7,7.8 C477.4,19.9 455,28.4 431.1,33.2 C411.9,12.7 384.4,0 354.5,0 C296.4,0 249.6,47.2 249.6,105 C249.6,113.3 250.3,121.3 252,128.9 C164.7,124.6 87.5,82.8 35.6,19.1 C26.5,34.8 21.2,52.8 21.2,72.2 C21.2,108.6 39.9,140.8 67.8,159.4 C50.9,159.1 34.4,154.2 20.4,146.5 C20.4,146.8 20.4,147.2 20.4,147.7 C20.4,198.7 56.8,241.1 104.5,250.8 C96,253.1 86.6,254.3 77,254.3 C70.3,254.3 63.5,253.9 57.1,252.5 C70.7,294.1 109.3,324.6 155.2,325.6 C119.5,353.5 74.1,370.4 25.1,370.4 C16.5,370.4 8.2,370 0,369 C46.5,399 101.6,416.1 161,416.1 C354.2,416.1 459.8,256.1 459.8,117.4 C459.8,112.8 459.6,108.3 459.4,103.8 C480.2,89 497.7,70.5 512,49.2 Z" id="Path"></path>
#           </svg>
#         </i>
#       </a>
#     </li>
#     <li class="cher-link-item cher-link-facebook" style="display: none;">
#       <a id="cher-link-email" class="cher-link" href="https://www.facebook.com/pulsarsec" title="Follow us on Facebook" rel="nofollow,noopener" target="_blank">
#         <i class="icon icon-facebook" style="background-image: none;">
#           <svg width="52px" height="97px" viewBox="0 0 52 97" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#             <path d="M50.1,0 L37.6,0 C23.6,0 14.5,9.3 14.5,23.7 L14.5,34.6 L2,34.6 C0.9,34.6 0,35.5 0,36.6 L0,52.4 C0,53.5 0.9,54.4 2,54.4 L14.5,54.4 L14.5,94.3 C14.5,95.4 15.4,96.3 16.5,96.3 L32.9,96.3 C34,96.3 34.9,95.4 34.9,94.3 L34.9,54.3 L49.6,54.3 C50.7,54.3 51.6,53.4 51.6,52.3 L51.6,36.5 C51.6,36 51.4,35.5 51,35.1 C50.6,34.7 50.1,34.5 49.6,34.5 L34.8,34.5 L34.8,25.3 C34.8,20.9 35.9,18.6 41.6,18.6 L50,18.6 C51.1,18.6 52,17.7 52,16.6 L52,2 C52,0.9 51.2,0 50.1,0 Z" id="Path"></path>
#           </svg>
#         </i>
#       </a>
#     </li>
#   </ul>
# </div></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget cm-copyright" style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_151811920816247" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><span id="hs_cos_wrapper_module_151811920816247_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text"><p><span> Copyright © 2020 Pulsar Security </span></p>
# <em>|</em>
# <p><span> <a href="https://www.pulsarsecurity.com/privacy-policy" rel="noopener">Privacy Policy</a></span></p>
# <em>|</em>
# <p><span> <a href="https://www.pulsarsecurity.com/terms" rel="noopener">Terms &amp; Conditions</a></span></p>
# <p class="dev"><span> <a href="https://www.commonplaces.com/" target="_blank" rel="noopener" alt="Website Design &amp; Development by CommonPlaces Interactive">Website Design &amp; Development by CommonPlaces Interactive</a></span></p></span></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
# </div>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
#     </div><!--end footer -->
# </div><!--end footer wrapper -->
#
#     <script src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js"></script>
# <script>hsjQuery = window['jQuery'];</script>
# <script>
# (function () {
#     window.addEventListener('load', function () {
#         setTimeout(function () {
#             var xhr = new XMLHttpRequest();
#             xhr.open('POST', '/_hcms/perf', true /*async*/);
#             xhr.setRequestHeader("Content-type", "application/json");
#             xhr.onreadystatechange = function () {
#                 // do nothing.
#             };
#             var connection = navigator.connection || navigator.mozConnection || navigator.webkitConnection;
#             function populateNetworkInfo(name, connection, info) {
#                 if (name in connection) {
#                     info[name] = connection[name];
#                 }
#             }
#             var networkInfo = {};
#             if (connection) {
#                 ['type', 'effectiveType', 'downlink', 'rtt'].forEach(function(name) {
#                     populateNetworkInfo(name, connection, networkInfo);
#                 });
#             }
#             var perfData = {
#                 url: location.href,
#                 portal: 6072841,
#                 content: 17570113547,
#                 group: -1,
#                 connection: networkInfo,
#                 timing: performance.timing
#             };
#             xhr.send(JSON.stringify(perfData));
#         }, 3000);  // Execute this 3 seconds after onload.
#     });
# })();
# </script>
#
# <script src="https://www.pulsarsecurity.com/hs-fs/hub/6072841/hub_generated/template_assets/16938991488/1647531504504/Pulsar/Coded_Files/pulsar.min.js"></script>
# <script>
# var hsVars = hsVars || {}; hsVars['language'] = 'en';
# </script>
#
# <script src="/hs/hsstatic/cos-i18n/static-1.53/bundles/project.js"></script>
# <script src="https://www.pulsarsecurity.com/hubfs/pulsar/slider/slick.min.js"></script>
# <script src="https://www.pulsarsecurity.com/hs-fs/hub/6072841/hub_generated/module_assets/45640589407/1661788873448/module_45640589407_certificates-slide.min.js"></script>
#
# <!-- Start of HubSpot Analytics Code -->
# <script type="text/javascript">
# var _hsq = _hsq || [];
# _hsq.push(["setContentType", "standard-page"]);
# _hsq.push(["setCanonicalUrl", "https:\/\/www.pulsarsecurity.com\/team"]);
# _hsq.push(["setPageId", "17570113547"]);
# _hsq.push(["setContentMetadata", {
#     "contentPageId": 17570113547,
#     "legacyPageId": "17570113547",
#     "contentFolderId": null,
#     "contentGroupId": null,
#     "abTestId": null,
#     "languageVariantId": 17570113547,
#     "languageCode": "en",
#
# }]);
# </script>
#
# <script type="text/javascript" id="hs-script-loader" async defer src="/hs/scriptloader/6072841.js"></script>
# <!-- End of HubSpot Analytics Code -->
#
#
# <script type="text/javascript">
# var hsVars = {
#     ticks: 1669508103367,
#     page_id: 17570113547,
#
#     content_group_id: 0,
#     portal_id: 6072841,
#     app_hs_base_url: "https://app.hubspot.com",
#     cp_hs_base_url: "https://cp.hubspot.com",
#     language: "en",
#     analytics_page_type: "standard-page",
#     analytics_page_id: "17570113547",
#     category_id: 1,
#     folder_id: 0,
#     is_hubspot_user: false
# }
# </script>
#
#
# <script defer src="/hs/hsstatic/HubspotToolsMenu/static-1.138/js/index.js"></script>
#
#
#
#
#
#     <!-- Generated by the HubSpot Template Builder - template version 1.03 -->
#
# </body></html>

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find(id="block-team")

# %%
print(results.prettify())
# Out:
# <section class="column-content block-content-team" id="block-team">
#  <div class="column-content-wrapper">
#   <ul class="block-team-list">
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/patrick-hynds">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="patrick-hynds" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/patrick-hynds.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Patrick Hynds
#        </h3>
#        <h4 class="block-team-role">
#         Chief Executive Officer
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/duane-laflotte">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="duane-laflotte" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/duane-laflotte.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Duane Laflotte
#        </h3>
#        <h4 class="block-team-role">
#         Chief Technology Officer, Senior Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="OSWE" src="https://www.pulsarsecurity.com/hubfs/OSWE.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="osce (1)" src="https://www.pulsarsecurity.com/hubfs/Certifications/osce%20(1).png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="oscp" src="https://www.pulsarsecurity.com/hubfs/Certifications/oscp.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GXPN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="OSEP" src="https://www.pulsarsecurity.com/hubfs/OSEP.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/sabine-hynds">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="Sabine" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/Sabine.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Sabine Hynds
#        </h3>
#        <h4 class="block-team-role">
#         Chief Financial Officer, Human Resources Manager
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/ahren-thielker">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="ahren-thielker" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/ahren-thielker.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Ahren Thielker
#        </h3>
#        <h4 class="block-team-role">
#         Chief Information Officer, Network Security Engineer, Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="Template_GPEN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="linkedin_thumb_GPYC_Dig_badge_logo-1" src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_GPYC_Dig_badge_logo-1.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="linkedin_thumb_Template_GAWN-1-1" src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_Template_GAWN-1-1.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GWAPT" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GWAPT.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/jarrod-laflotte">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="Duane-laflotte" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/Duane-laflotte.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Jarrod Laflotte
#        </h3>
#        <h4 class="block-team-role">
#         Researcher, Senior Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="oscp" src="https://www.pulsarsecurity.com/hubfs/oscp.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GXPN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486" src="https://www.pulsarsecurity.com/hubfs/AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="OSEP" src="https://www.pulsarsecurity.com/hubfs/OSEP.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/vaughn-temple">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="vaughn" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/vaughn.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Vaughn Temple
#        </h3>
#        <h4 class="block-team-role">
#         Researcher, Senior Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="oscp" src="https://www.pulsarsecurity.com/hubfs/oscp.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GXPN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="cissp" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/certifications/cissp.gif"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486" src="https://www.pulsarsecurity.com/hubfs/AWS-Certified_Solutions-Architect_Associate_512x512.d82aee07920970350c427c8d0542bc239180a486.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="OSEP" src="https://www.pulsarsecurity.com/hubfs/OSEP.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/tim-connell">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="tim-connell" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/tim-connell.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Tim Connell
#        </h3>
#        <h4 class="block-team-role">
#         Director, Cybersecurity Services Delivery
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="OSCP" src="https://www.pulsarsecurity.com/hubfs/oscp.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="WiFu-OSWP-badge" src="https://www.pulsarsecurity.com/hubfs/WiFu-OSWP-badge.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="linkedin_thumb_Template_GAWN-1-1" src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_Template_GAWN-1-1.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GPEN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GCIA" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GCIA.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/manny-resendes">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="manny" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/manny.jpeg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Manny Resendes
#        </h3>
#        <h4 class="block-team-role">
#         Software Development Team Manager
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/jason-nickola">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="jason-nickola" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/jason-nickola.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Jason Nickola
#        </h3>
#        <h4 class="block-team-role">
#         Senior Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="GSE_352x352" src="https://www.pulsarsecurity.com/hubfs/Certifications/GSE_352x352.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="osce" src="https://www.pulsarsecurity.com/hubfs/osce.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GXPN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GXPN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="oscp" src="https://www.pulsarsecurity.com/hubfs/oscp.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GREM" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GREM.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/corey-belanger">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="corey-belanger" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/corey-belanger.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Corey Belanger
#        </h3>
#        <h4 class="block-team-role">
#         QA Lead, Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="Template_GCIH" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GCIH.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="linkedin_thumb_GPYC_Dig_badge_logo-1" src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_GPYC_Dig_badge_logo-1.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GWAPT" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GWAPT.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GPEN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="oscp" src="https://www.pulsarsecurity.com/hubfs/oscp.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/marshall-thompson">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="marshall-thompson" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/marshall-thompson.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Marshall Thompson
#        </h3>
#        <h4 class="block-team-role">
#         Software Engineer, Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="Template_GWAPT" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GWAPT.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="linkedin_thumb_GPYC_Dig_badge_logo-1" src="https://www.pulsarsecurity.com/hubfs/Certifications/linkedin_thumb_GPYC_Dig_badge_logo-1.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="Template_GPEN" src="https://www.pulsarsecurity.com/hubfs/Certifications/Template_GPEN.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="comptia-network" src="https://www.pulsarsecurity.com/hubfs/Certifications/comptia-network.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/yavuz-dereli">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="yavuz-dereli" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/yavuz-dereli.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Yavuz Dereli
#        </h3>
#        <h4 class="block-team-role">
#         Network Engineer
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="CCNA" src="https://www.pulsarsecurity.com/hubfs/CCNA-ACS-263x230.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="MTA-Database-Fundamentals-2019" src="https://www.pulsarsecurity.com/hubfs/MTA-Database-Fundamentals-2019.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="MTA-Security-Fundamentals-2019" src="https://www.pulsarsecurity.com/hubfs/MTA-Security-Fundamentals-2019.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/wes-molaski">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="wes-molaski" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/wes-molaski.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Wes Molaski
#        </h3>
#        <h4 class="block-team-role">
#         Security Consultant
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/peyton-somerville">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="peyton" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/peyton.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Peyton Somerville
#        </h3>
#        <h4 class="block-team-role">
#         Junior Security Engineer, leads Pulsar Explore Internship Program
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/jill-stagner">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="jill" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/jill.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Jill Stagner
#        </h3>
#        <h4 class="block-team-role">
#         Director of Marketing and Program Development
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/katie-gusella">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="Katie-Gusella" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/IMG_0194.jpeg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Katie Gusella
#        </h3>
#        <h4 class="block-team-role">
#         Director of Business Development
#        </h4>
#        <ul class="block-team-certifications-list">
#         <li class="block-team-certifications-item">
#          <img alt="BMI_Club_Management__3_" src="https://www.pulsarsecurity.com/hubfs/BMI_Club_Management__3_.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="BMI_Leadership_Principles__3_" src="https://www.pulsarsecurity.com/hubfs/BMI_Leadership_Principles__3_.png"/>
#         </li>
#         <li class="block-team-certifications-item">
#          <img alt="BMI_GM-COO__3_" src="https://www.pulsarsecurity.com/hubfs/BMI_GM-COO__3_.png"/>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/jim-bail">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="jim-bail" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/jim-bail.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Jim Bail
#        </h3>
#        <h4 class="block-team-role">
#         Senior Enterprise Account Manager
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="block-team-item">
#     <a class="block-team-link" href="https://www.pulsarsecurity.com/nikki-telowitz">
#      <div class="block-team-wrapper">
#       <div class="block-team-left">
#        <img alt="nikki-telowitz" class="block-team-image" src="https://www.pulsarsecurity.com/hubfs/pulsar/images/team/nikki-telowitz.jpg"/>
#       </div>
#       <div class="block-team-right">
#        <h3 class="block-team-name">
#         Nikki Telowitz
#        </h3>
#        <h4 class="block-team-role">
#         Senior Enterprise Account Manager
#        </h4>
#        <ul class="block-team-certifications-list">
#        </ul>
#       </div>
#      </div>
#     </a>
#    </li>
#   </ul>
#  </div>
# </section>

# %%
name_elements = results.find_all("h3", class_="block-team-name")

# %%
for name_element in name_elements:
    print(name_element, end="\n"*2)
# Out:
# <h3 class="block-team-name">Patrick Hynds</h3>
#
# <h3 class="block-team-name">Duane Laflotte</h3>
#
# <h3 class="block-team-name">Sabine Hynds</h3>
#
# <h3 class="block-team-name">Ahren Thielker</h3>
#
# <h3 class="block-team-name">Jarrod Laflotte</h3>
#
# <h3 class="block-team-name">Vaughn Temple</h3>
#
# <h3 class="block-team-name">Tim Connell</h3>
#
# <h3 class="block-team-name">Manny Resendes</h3>
#
# <h3 class="block-team-name">Jason Nickola</h3>
#
# <h3 class="block-team-name">Corey Belanger</h3>
#
# <h3 class="block-team-name">Marshall Thompson</h3>
#
# <h3 class="block-team-name">Yavuz Dereli</h3>
#
# <h3 class="block-team-name">Wes Molaski</h3>
#
# <h3 class="block-team-name">Peyton Somerville</h3>
#
# <h3 class="block-team-name">Jill Stagner</h3>
#
# <h3 class="block-team-name">Katie Gusella</h3>
#
# <h3 class="block-team-name">Jim Bail</h3>
#
# <h3 class="block-team-name">Nikki Telowitz</h3>

# %%
for name_element in name_elements:
    print(name_element.text)
    print()
# Out:
# Patrick Hynds
#
# Duane Laflotte
#
# Sabine Hynds
#
# Ahren Thielker
#
# Jarrod Laflotte
#
# Vaughn Temple
#
# Tim Connell
#
# Manny Resendes
#
# Jason Nickola
#
# Corey Belanger
#
# Marshall Thompson
#
# Yavuz Dereli
#
# Wes Molaski
#
# Peyton Somerville
#
# Jill Stagner
#
# Katie Gusella
#
# Jim Bail
#
# Nikki Telowitz
